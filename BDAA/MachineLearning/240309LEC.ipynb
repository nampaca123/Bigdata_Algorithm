# %%
import seaborn as sns

# %%
tt=sns.load_dataset('titanic')

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd

# %%
#기본적인 판다스의 다양한 문법
#판다스는 dataframe,sereis 두 가지로 메인이 나뉜다.
#2차원은 df(데이터프레임), 1차원은 series(시리즈)

type(tt)
# Out:
# pandas.core.frame.DataFrame

# %%
tt.shape #행과 열을 반환
# Out:
# (891, 15)

# %%
tt.columns #컬럼만 추출하고 싶은 경우
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
tt_col = list (tt.columns)
tt_col
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
tt.info() #info 데이터 타입의 다양한 정보를 얻을 수 있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
tt.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
tt.head() #디폴트로 앞 5개 값을 추출
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tt.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
tt.tail(10) #맨 끝 기준
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
#행과 열로 이루어진 데이터프레임
#df[컬럼]
#df.컬럼

# %%
tt['survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
tt[['survived', 'age']]
# Out:
#      survived   age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %%
#변수처럼 내가 원하는 데이터를 넣을 수 있다.
tt.sp=tt[['age', 'survived', 'fare']]
tt.sp
# Out:
# C:\Users\nampa\AppData\Local\Temp\ipykernel_13708\1529287447.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   tt.sp=tt[['age', 'survived', 'fare']]
#       age  survived     fare
# 0    22.0         0   7.2500
# 1    38.0         1  71.2833
# 2    26.0         1   7.9250
# 3    35.0         1  53.1000
# 4    35.0         0   8.0500
# ..    ...       ...      ...
# 886  27.0         0  13.0000
# 887  19.0         1  30.0000
# 888   NaN         0  23.4500
# 889  26.0         1  30.0000
# 890  32.0         0   7.7500
#
# [891 rows x 3 columns]

# %%
#행 데이터 추출하기
#인덱스 기준에서의 문법을 이해하자
    # loc: 행 인덱스 기준으로 추출 (이름으로 추출이 가능), 변수의 개념으로 추출도 가능하다! (-1 끝 값은 출력이 불가능)
    # iloc: 행 인덱스 기준으로 추출 (추출한 인덱스 기준), 번호로만 추출이 가능 (-1 끝 값 출력 가능)
# 리스트에서 index[]와 동일

# %%
tt.loc[0]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
tt.iloc[0]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
tt.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\nampa\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tt.loc[-1]
#
# File c:\Users\nampa\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# ...

# %%
nrow=tt.shape[0]
lastindex=nrow-1
tt.loc[lastindex]
#맨 끝값을 출력해야 할 시 이렇게 변수로 넣으면 가능하다
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
midnum=75
tt.loc[midnum]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   25.0
# sibsp                    0
# parch                    0
# fare                  7.65
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                     F
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 75, dtype: object

# %%
tt.loc[[1, 10, 20, 30, 890]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 30          0       1    male  40.0      0      0  27.7208        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 20     man        True  NaN  Southampton    no   True
# 30     man        True  NaN    Cherbourg    no   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# range 슬라이싱을 가지고 동일하게 적용할 수 있다
# loc, iloc 슬라이싱을 통해서 데이터 범위에 range를 지정할 수 있다
# [:] 전체
# [시작점:끝점:증가폭] range 함수와 동일하게 추출할 수 있다!

tt.loc[::2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.iloc[1:10:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 3  woman       False    C  Southampton   yes  False
# 5    man        True  NaN   Queenstown    no   True
# 7  child       False  NaN  Southampton    no  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
tt.loc[1:40,['age']]
# Out:
#      age
# 1   38.0
# 2   26.0
# 3   35.0
# 4   35.0
# 5    NaN
# 6   54.0
# 7    2.0
# 8   27.0
# 9   14.0
# 10   4.0
# 11  58.0
# 12  20.0
# 13  39.0
# 14  14.0
# 15  55.0
# 16   2.0
# 17   NaN
# 18  31.0
# 19   NaN
# 20  35.0
# 21  34.0
# 22  15.0
# 23  28.0
# 24   8.0
# 25  38.0
# 26   NaN
# 27  19.0
# 28   NaN
# 29   NaN
# 30  40.0
# 31   NaN
# 32   NaN
# 33  66.0
# 34  28.0
# 35  42.0
# 36   NaN
# 37  21.0
# 38  18.0
# 39  14.0
# 40  40.0

# %%
tt.loc[1:20:2, ['age', 'survived']]
# Out:
#      age  survived
# 1   38.0         1
# 3   35.0         1
# 5    NaN         0
# 7    2.0         0
# 9   14.0         1
# 11  58.0         1
# 13  39.0         0
# 15  55.0         1
# 17   NaN         1
# 19   NaN         1

# %%
tt.iloc[1:10:2,[3,4,-1]]
#iloc은 넘버로만 지정이 가능하므로 이렇게 접근해야 한다
# Out:
#     age  sibsp  alone
# 1  38.0      1  False
# 3  35.0      1  False
# 5   NaN      0   True
# 7   2.0      3  False
# 9  14.0      1  False

# %%
tt.loc[3][['age','class']]
# Out:
# age       35.0
# class    First
# Name: 3, dtype: object

# %%
tt[['age','class']].loc[3]
# Out:
# age       35.0
# class    First
# Name: 3, dtype: object

# %%
tt.fare.mean()
# Out:
# 32.204207968574636

# %%
tt.fare.sum()
# Out:
# 28693.9493

# %%
tt.fare.count()
# Out:
# 891

# %%
# pclass별로 평균 fare은 얼마인가?
# groupby 그룹으로 묶어서 계산할 수 있다
# groupby ('그룹을 묶을 컬럼')['통계치를 볼 컬럼'].원하는 통계치의 함수()
tt.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
tt.groupby('sex')['survived'].sum()
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64
